# %%
from gidnet_qubit_reuse_algorithm.gidnet_qra import (modified_compile_dynamic_circuit
                                                    )

from helper_functions.benchmarks import generate_circ
from qiskit import QuantumCircuit
import numpy as np

# %%
from gidnet_qubit_reuse_algorithm.gidnet_qra import (safe_eval,
                                                     create_qiskit_and_qnet_GRCS_circuits,)
import time
import os

# %%
circuit_sizes = ["4x4", "4x5", "5x5", "5x6", "6x6", "6x7", "7x7", "7x8", "8x8", "8x9",
                "9x9", "9x10", "10x10", "10x11", "11x11", "11x12", "12x12"]

directory_path = "../data"
cycle_num = 10
random_shots = 10


gidnet_plus_average_time = []
gidnet_plus_std_time = []
gidnet_plus_qubit_width = []

for i, num_qubits in enumerate(circuit_sizes):
    print("circuit", i+1, "running")
    qiskit_circuit, _ = create_qiskit_and_qnet_GRCS_circuits(num_qubits, cycle_num, directory_path)

    gidnet_plus_time = %timeit -o modified_compile_dynamic_circuit(qiskit_circuit, shots=random_shots, algorithm_type="gidnet", improved_gidnet=False)

    compiled_gidnet_circuit = modified_compile_dynamic_circuit(qiskit_circuit, shots=random_shots, algorithm_type="gidnet",
                                                      improved_gidnet=False)

    # Data colation
    gidnet_plus_average_time.append(gidnet_plus_time.average)
    gidnet_plus_std_time.append(gidnet_plus_time.stdev)
    gidnet_plus_qubit_width.append(compiled_gidnet_circuit.num_qubits)
# Out:
# circuit 1 running
# 65 ms ± 3.96 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# circuit 2 running
# 117 ms ± 12.4 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# circuit 3 running
# 173 ms ± 18.1 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# circuit 4 running
# 243 ms ± 6.65 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 5 running
# 481 ms ± 20 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 6 running
# 758 ms ± 42.8 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 7 running
# 1.19 s ± 37.6 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 8 running
# 1.82 s ± 197 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 9 running
# 3.05 s ± 205 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 10 running
# 4.33 s ± 240 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 11 running
# 7.58 s ± 713 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 12 running
# 10.3 s ± 709 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 13 running
# 19.6 s ± 1.4 s per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 14 running
# 27.2 s ± 668 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 15 running
# 38.7 s ± 1.89 s per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 16 running
# 53.2 s ± 4.54 s per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 17 running
# 56.3 s ± 6.75 s per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# gidnet_plus_qubit_width

# %%
import pandas as pd
# Convert lists to a dictionary
data = {
    'Circuit Sizes': [safe_eval(s) for s in circuit_sizes],
    'GidNET Average Runtime': gidnet_plus_average_time,  # Added comma
    'GidNET Stdev Runtime': gidnet_plus_std_time,  # Added comma
    'GidNET Width': gidnet_plus_qubit_width,
}

# Assuming pandas is imported as pd
import pandas as pd

# Convert dictionary to DataFrame
df = pd.DataFrame(data)

# Save DataFrame to CSV
df.to_csv('data_supremacy_cct/GidNET_v03_width_and_runtime_supremacy_cct_cycle_10_data.csv', index=False)

# %%
df
# Out:
#     Circuit Sizes  GidNET Average Runtime  GidNET Stdev Runtime  GidNET Width
# 0              16                0.064986              0.003964             9
# 1              20                0.117474              0.012380            10
# 2              25                0.172834              0.018143            11
# 3              30                0.242605              0.006645            11
# 4              36                0.481354              0.019968            14
# 5              42                0.758119              0.042751            16
# 6              49                1.186263              0.037648            17
# 7              56                1.820690              0.197280            19
# 8              64                3.049326              0.204515            19
# 9              72                4.330267              0.239866            21
# 10             81                7.582267              0.712864            23
# 11             90               10.296968              0.709131            24
# 12            100               19.626405              1.401152            26
# 13            110               27.178662              0.667790            31
# 14            121               38.687552              1.885349            31
# 15            132               53.192880              4.541635            28
# 16            144               56.341140              6.751417            32

# %%
circuit_sizes = ["4x4", "4x5", "5x5", "5x6", "6x6", "6x7", "7x7", "7x8", "8x8", "8x9",
                "9x9", "9x10", "10x10", "10x11", "11x11", "11x12", "12x12"]

directory_path = "../data"
cycle_num = 10
random_shots = 10


gidnet_plus_average_time = []
gidnet_plus_std_time = []
gidnet_plus_qubit_width = []

for i, num_qubits in enumerate(circuit_sizes):
    print("circuit", i+1, "running")
    qiskit_circuit, _ = create_qiskit_and_qnet_GRCS_circuits(num_qubits, cycle_num, directory_path)
    print(qiskit_circuit.depth())
# Out:
# circuit 1 running
# 12
# circuit 2 running
# 12
# circuit 3 running
# 12
# circuit 4 running
# 12
# circuit 5 running
# 12
# circuit 6 running
# 12
# circuit 7 running
# 12
# circuit 8 running
# 12
# circuit 9 running
# 12
# circuit 10 running
# 12
# circuit 11 running
# 12
# circuit 12 running
# 12
# circuit 13 running
# 12
# circuit 14 running
# 12
# circuit 15 running
# 12
# circuit 16 running
# 12
# circuit 17 running
# 12
