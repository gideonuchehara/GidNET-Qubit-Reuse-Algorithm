# %%
from gidnet_qubit_reuse_algorithm.gidnet_qra import apply_qiskit_qubit_reuse, create_qiskit_and_qnet_GRCS_circuits, safe_eval
import time

# %%
circuit_sizes = ["4x4", "4x5", "5x5", "5x6", "6x6", "6x7", "7x7", "7x8", "8x8", "8x9",
                "9x9", "9x10", "10x10", "10x11", "11x11", "11x12", "12x12"]

directory_path = "./data"
cycle_num = 13

qiskit_average_time = []
qiskit_std_time = []
qiskit_qubit_width = []

for i, num_qubits in enumerate(circuit_sizes):
    print("circuit", i+1, "running")
    qiskit_circuit, _ = create_qiskit_and_qnet_GRCS_circuits(num_qubits, cycle_num, directory_path)
    
    
    qiskit_time = %timeit -o apply_qiskit_qubit_reuse(qiskit_circuit)
    compiled_qiskit_circuit = apply_qiskit_qubit_reuse(qiskit_circuit)

    qiskit_average_time.append(qiskit_time.average)
    qiskit_std_time.append(qiskit_time.stdev)
    qiskit_qubit_width.append(compiled_qiskit_circuit.num_qubits)
# Out:
# circuit 1 running
# 107 ms ± 6.75 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# circuit 2 running
# 157 ms ± 8.84 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# circuit 3 running
# 220 ms ± 6.76 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# circuit 4 running
# 296 ms ± 30.5 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 5 running
# 405 ms ± 19.2 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 6 running
# 570 ms ± 20.3 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 7 running
# 743 ms ± 37.8 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 8 running
# 890 ms ± 37.2 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 9 running
# 1.13 s ± 57.7 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 10 running
# 1.33 s ± 51 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 11 running
# 1.65 s ± 34.6 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 12 running
# 1.96 s ± 66.7 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 13 running
# 2.4 s ± 159 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 14 running
# 2.77 s ± 48.5 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 15 running
# 3.27 s ± 101 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 16 running
# 3.82 s ± 102 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 17 running
# 4.22 s ± 110 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
import pandas as pd
# Convert lists to a dictionary
data = {
    'Circuit Sizes': [safe_eval(s) for s in circuit_sizes],
    'Qiskit Average Runtime': qiskit_average_time,  # Added comma
    'Qiskit Stdev Runtime': qiskit_std_time,  # Added comma
    'Qiskit Width': qiskit_qubit_width,
}

# Assuming pandas is imported as pd
import pandas as pd

# Convert dictionary to DataFrame
df = pd.DataFrame(data)

# Save DataFrame to CSV
df.to_csv('data_supremacy_cct/Qiskit_width_and_runtime_supremacy_cct_data.csv', index=False)

# %%
df
# Out:
#     Circuit Sizes  Qiskit Average Runtime  Qiskit Stdev Runtime  Qiskit Width
# 0              16                0.106852              0.006754            10
# 1              20                0.157198              0.008842            13
# 2              25                0.219926              0.006763            16
# 3              30                0.295821              0.030477            19
# 4              36                0.405044              0.019157            26
# 5              42                0.570080              0.020290            28
# 6              49                0.742703              0.037780            39
# 7              56                0.889731              0.037168            42
# 8              64                1.126462              0.057661            48
# 9              72                1.331061              0.051000            51
# 10             81                1.647279              0.034629            61
# 11             90                1.964794              0.066653            66
# 12            100                2.399935              0.158936            75
# 13            110                2.769940              0.048533            79
# 14            121                3.267382              0.101419            90
# 15            132                3.822136              0.101947            99
# 16            144                4.217988              0.110461           104
