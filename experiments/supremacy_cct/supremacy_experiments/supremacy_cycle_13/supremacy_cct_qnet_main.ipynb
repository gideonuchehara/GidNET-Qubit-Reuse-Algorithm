# %%
from gidnet_qubit_reuse_algorithm.gidnet_qra import (safe_eval,
                                                     create_qiskit_and_qnet_GRCS_circuits,
                                                     compute_qubit_reuse_sets, 
                                                    compile_dynamic_circuit)
import time

# %%
circuit_sizes = ["4x4", "4x5", "5x5", "5x6", "6x6", "6x7", "7x7", "7x8", "8x8", "8x9",
                "9x9", "9x10", "10x10", "10x11", "11x11", "11x12", "12x12"]

random_shots = 10 # shots for qnet algorithm

directory_path = "./data"
cycle_num = 13

qnet_average_time = []
qnet_std_time = []
qnet_qubit_width = []

for i, num_qubits in enumerate(circuit_sizes):
    print("circuit", i+1, "running")
    qiskit_circuit, qnet_circuit = create_qiskit_and_qnet_GRCS_circuits(num_qubits, cycle_num, directory_path)
    qnet_time = %timeit -o qnet_circuit.reduce(method="random_greedy", shots=random_shots)
    qnet_circuit.reduce(method="random_greedy", shots=random_shots)

    qnet_average_time.append(qnet_time.average)
    qnet_std_time.append(qnet_time.stdev)
    qnet_qubit_width.append(qnet_circuit.width)
# Out:
# circuit 1 running
# The slowest run took 4.92 times longer than the fastest. This could mean that an intermediate result is being cached.
# 53.7 ms ± 23.8 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# circuit 2 running
# 2.91 ms ± 344 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 3 running
# 4.63 ms ± 783 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 4 running
# 4.52 ms ± 140 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 5 running
# 5.62 ms ± 216 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 6 running
# 6.41 ms ± 571 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 7 running
# 7.78 ms ± 553 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 8 running
# 8.86 ms ± 739 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 9 running
# 10.1 ms ± 571 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 10 running
# 11.4 ms ± 748 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 11 running
# 18.3 ms ± 7.33 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 12 running
# 14.3 ms ± 777 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 13 running
# 15.4 ms ± 899 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 14 running
# 19.8 ms ± 1.28 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 15 running
# 21.3 ms ± 1.14 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 16 running
# 21.7 ms ± 1.13 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 17 running
# 24.1 ms ± 1.5 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
import pandas as pd
# Convert lists to a dictionary
data = {
    'Circuit Sizes': [safe_eval(s) for s in circuit_sizes],
    'QNET-main Average Runtime': qnet_average_time,  # Added comma
    'QNET-main Stdev Runtime': qnet_std_time,  # Added comma
    'QNET-main Width': qnet_qubit_width
}

# Assuming pandas is imported as pd
import pandas as pd

# Convert dictionary to DataFrame
df = pd.DataFrame(data)

# Save DataFrame to CSV
df.to_csv('data_supremacy_cct/QNET-main_width_and_runtime_supremacy_cct_data.csv', index=False)

# %%
df
# Out:
#     Circuit Sizes  QNET-main Average Runtime  QNET-main Stdev Runtime  \
# 0              16                   0.053667                 0.023831
# 1              20                   0.002908                 0.000344
# 2              25                   0.004628                 0.000783
# 3              30                   0.004518                 0.000140
# 4              36                   0.005621                 0.000216
# 5              42                   0.006408                 0.000571
# 6              49                   0.007776                 0.000553
# 7              56                   0.008856                 0.000739
# 8              64                   0.010114                 0.000571
# 9              72                   0.011380                 0.000748
# 10             81                   0.018286                 0.007334
# 11             90                   0.014325                 0.000777
# 12            100                   0.015422                 0.000899
# 13            110                   0.019811                 0.001282
# 14            121                   0.021327                 0.001136
# 15            132                   0.021748                 0.001134
# 16            144                   0.024109                 0.001502
#
#     QNET-main Width
# 0                10
# 1                12
# 2                14
# 3                16
# 4                19
# 5                20
# 6                24
# 7                24
# 8                30
# 9                29
# 10               30
# 11               32
# 12               32
# 13               36
# 14               39
# 15               38
# 16               41
