# %%
from gidnet_qubit_reuse_algorithm.gidnet_qra import (modified_compute_qubit_reuse_sets
                                                    )

from helper_functions.benchmarks import generate_circ
from qiskit import QuantumCircuit
import numpy as np

# %%
circuit_sizes = [16, 20, 25, 30, 36, 42, 49, 56, 64, 72, 81, 90, 100, 110, 121, 132, 144]
random_shots = 10 # shots for qnet algorithm

gidnet_average_time = []
gidnet_std_time = []
gidnet_qubit_width = []

for i, circuit_size in enumerate(circuit_sizes):
    print("circuit", i+1, "running")
    circuit_type = "supremacy"

    supremacy_circuit = generate_circ(
            num_qubits=circuit_size,
            depth=1,
            circuit_type=circuit_type,
            reg_name="q",
            connected_only=True,
            seed=None,
    )

    if supremacy_circuit is not None:
        supremacy_circuit.measure_all()


    #### GIDNET EXPERIMENT BEGINS #####
    gidnet_time = %timeit -o modified_compute_qubit_reuse_sets(supremacy_circuit, shots=random_shots)
    gidnet_result = modified_compute_qubit_reuse_sets(supremacy_circuit, shots=random_shots)

    gidnet_average_time.append(gidnet_time.average)
    gidnet_std_time.append(gidnet_time.stdev)
    gidnet_qubit_width.append(len(gidnet_result))
# Out:
# circuit 1 running
# 54.1 ms ± 1.66 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# circuit 2 running
# 87.9 ms ± 1.43 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# circuit 3 running
# 163 ms ± 5.5 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# circuit 4 running
# 262 ms ± 7.78 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 5 running
# 503 ms ± 14.3 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 6 running
# 880 ms ± 42.4 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 7 running
# 1.36 s ± 72.1 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 8 running
# 1.93 s ± 111 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 9 running
# 3.49 s ± 55.5 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 10 running
# 5.02 s ± 268 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 11 running
# 7.06 s ± 168 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 12 running
# 10.3 s ± 180 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 13 running
# 14.5 s ± 211 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 14 running
# 22.4 s ± 1.74 s per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 15 running
# 27.8 s ± 513 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 16 running
# 39.3 s ± 574 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 17 running
# 52.4 s ± 1.07 s per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
import pandas as pd
# Convert lists to a dictionary
data = {
    'Circuit Sizes': circuit_sizes,
    'GidNET Average Runtime': gidnet_average_time,  # Added comma
    'GidNET Stdev Runtime': gidnet_std_time,  # Added comma
    'GidNET Width': gidnet_qubit_width,
}

# Assuming pandas is imported as pd
import pandas as pd

# Convert dictionary to DataFrame
df = pd.DataFrame(data)

# Save DataFrame to CSV
df.to_csv('GidNET_v02_width_and_runtime_supremacy_cct_data.csv', index=False)

# %%
df
# Out:
#     Circuit Sizes  GidNET Average Runtime  GidNET Stdev Runtime  GidNET Width
# 0              16                0.054118              0.001662             8
# 1              20                0.087888              0.001434             9
# 2              25                0.163495              0.005500            10
# 3              30                0.261959              0.007779            11
# 4              36                0.502674              0.014305            12
# 5              42                0.880157              0.042355            12
# 6              49                1.358781              0.072060            14
# 7              56                1.928320              0.111255            15
# 8              64                3.486160              0.055450            18
# 9              72                5.015760              0.268074            18
# 10             81                7.057501              0.168200            18
# 11             90               10.292317              0.180325            20
# 12            100               14.511020              0.211155            22
# 13            110               22.369285              1.737868            23
# 14            121               27.825516              0.513073            26
# 15            132               39.295459              0.574169            26
# 16            144               52.438135              1.070460            28
