# %%
from gidnet_qubit_reuse_algorithm.gidnet_qra import (modified_compile_dynamic_circuit
                                                    )

from helper_functions.benchmarks import generate_circ
from qiskit import QuantumCircuit
import numpy as np

# %%
from gidnet_qubit_reuse_algorithm.gidnet_qra import (safe_eval,
                                                     create_qiskit_and_qnet_GRCS_circuits,)
import time
import os

# %%
circuit_sizes = ["4x4", "4x5", "5x5", "5x6", "6x6", "6x7", "7x7", "7x8", "8x8", "8x9",
                "9x9", "9x10", "10x10", "10x11", "11x11", "11x12", "12x12"]

directory_path = "../data"
cycle_num = 13
random_shots = 10


gidnet_plus_average_time = []
gidnet_plus_std_time = []
gidnet_plus_qubit_width = []

for i, num_qubits in enumerate(circuit_sizes):
    print("circuit", i+1, "running")
    qiskit_circuit, _ = create_qiskit_and_qnet_GRCS_circuits(num_qubits, cycle_num, directory_path)

    gidnet_plus_time = %timeit -o modified_compile_dynamic_circuit(qiskit_circuit, shots=random_shots, algorithm_type="gidnet", improved_gidnet=False)

    compiled_gidnet_circuit = modified_compile_dynamic_circuit(qiskit_circuit, shots=random_shots, algorithm_type="gidnet",
                                                      improved_gidnet=False)

    # Data colation
    gidnet_plus_average_time.append(gidnet_plus_time.average)
    gidnet_plus_std_time.append(gidnet_plus_time.stdev)
    gidnet_plus_qubit_width.append(compiled_gidnet_circuit.num_qubits)
# Out:
# circuit 1 running
# 88.9 ms ± 6.16 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# circuit 2 running
# 111 ms ± 7.73 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# circuit 3 running
# 193 ms ± 9.12 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# circuit 4 running
# 287 ms ± 42.1 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 5 running
# 417 ms ± 33.7 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 6 running
# 608 ms ± 60.3 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 7 running
# 1.03 s ± 49.6 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 8 running
# 1.68 s ± 120 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 9 running
# 2.48 s ± 211 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 10 running
# 3.54 s ± 145 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 11 running
# 5.7 s ± 510 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 12 running
# 9.73 s ± 814 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 13 running
# 14.2 s ± 438 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 14 running
# 18.8 s ± 744 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 15 running
# 26.1 s ± 1.34 s per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 16 running
# 41 s ± 1.12 s per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 17 running
# 44.9 s ± 1.3 s per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
import pandas as pd
# Convert lists to a dictionary
data = {
    'Circuit Sizes': [safe_eval(s) for s in circuit_sizes],
    'GidNET Average Runtime': gidnet_plus_average_time,  # Added comma
    'GidNET Stdev Runtime': gidnet_plus_std_time,  # Added comma
    'GidNET Width': gidnet_plus_qubit_width,
}

# Assuming pandas is imported as pd
import pandas as pd

# Convert dictionary to DataFrame
df = pd.DataFrame(data)

# Save DataFrame to CSV
df.to_csv('data_supremacy_cct/GidNET_v03_width_and_runtime_supremacy_cct_cycle_13_data.csv', index=False)

# %%
df
# Out:
#     Circuit Sizes  GidNET Average Runtime  GidNET Stdev Runtime  GidNET Width
# 0              16                0.088862              0.006162            10
# 1              20                0.110630              0.007733            12
# 2              25                0.192654              0.009119            12
# 3              30                0.287176              0.042142            16
# 4              36                0.417066              0.033748            19
# 5              42                0.608109              0.060310            20
# 6              49                1.030592              0.049587            23
# 7              56                1.682718              0.120457            25
# 8              64                2.481435              0.211176            29
# 9              72                3.538063              0.145300            29
# 10             81                5.704044              0.509682            32
# 11             90                9.734121              0.814185            30
# 12            100               14.221327              0.437786            35
# 13            110               18.782127              0.744325            37
# 14            121               26.065202              1.336712            38
# 15            132               41.037860              1.123636            42
# 16            144               44.946429              1.299635            44

# %%
qiskit_circuit.depth()
# Out:
# 15

# %%
circuit_sizes = ["4x4", "4x5", "5x5", "5x6", "6x6", "6x7", "7x7", "7x8", "8x8", "8x9",
                "9x9", "9x10", "10x10", "10x11", "11x11", "11x12", "12x12"]

directory_path = "../data"
cycle_num = 13
random_shots = 10


gidnet_plus_average_time = []
gidnet_plus_std_time = []
gidnet_plus_qubit_width = []

for i, num_qubits in enumerate(circuit_sizes):
    print("circuit", i+1, "running")
    qiskit_circuit, _ = create_qiskit_and_qnet_GRCS_circuits(num_qubits, cycle_num, directory_path)
    print(qiskit_circuit.depth())
# Out:
# circuit 1 running
# 15
# circuit 2 running
# 15
# circuit 3 running
# 15
# circuit 4 running
# 15
# circuit 5 running
# 15
# circuit 6 running
# 15
# circuit 7 running
# 15
# circuit 8 running
# 15
# circuit 9 running
# 15
# circuit 10 running
# 15
# circuit 11 running
# 15
# circuit 12 running
# 15
# circuit 13 running
# 15
# circuit 14 running
# 15
# circuit 15 running
# 15
# circuit 16 running
# 15
# circuit 17 running
# 15
