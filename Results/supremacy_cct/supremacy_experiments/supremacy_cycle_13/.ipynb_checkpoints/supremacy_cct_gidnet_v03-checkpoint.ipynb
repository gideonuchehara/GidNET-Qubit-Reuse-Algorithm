# %%
from gidnet_qubit_reuse_algorithm.gidnet_qra import (modified_compile_dynamic_circuit
                                                    )

from helper_functions.benchmarks import generate_circ
from qiskit import QuantumCircuit
import numpy as np

# %%
from gidnet_qubit_reuse_algorithm.gidnet_qra import (safe_eval,
                                                     create_qiskit_and_qnet_GRCS_circuits,)
import time
import os

# %%
circuit_sizes = ["4x4", "4x5", "5x5", "5x6", "6x6", "6x7", "7x7", "7x8", "8x8", "8x9",
                "9x9", "9x10", "10x10", "10x11", "11x11", "11x12", "12x12"]

directory_path = "../data"
cycle_num = 13
random_shots = 10


gidnet_plus_average_time = []
gidnet_plus_std_time = []
gidnet_plus_qubit_width = []

for i, num_qubits in enumerate(circuit_sizes):
    print("circuit", i+1, "running")
    qiskit_circuit, _ = create_qiskit_and_qnet_GRCS_circuits(num_qubits, cycle_num, directory_path)

    gidnet_plus_time = %timeit -o modified_compile_dynamic_circuit(qiskit_circuit, shots=random_shots, algorithm_type="gidnet", improved_gidnet=False)

    compiled_gidnet_circuit = modified_compile_dynamic_circuit(qiskit_circuit, shots=random_shots, algorithm_type="gidnet",
                                                      improved_gidnet=False)

    # Data colation
    gidnet_plus_average_time.append(gidnet_plus_time.average)
    gidnet_plus_std_time.append(gidnet_plus_time.stdev)
    gidnet_plus_qubit_width.append(compiled_gidnet_circuit.num_qubits)
# Out:
# circuit 1 running
# 56.7 ms ± 3.93 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# circuit 2 running
# 83.3 ms ± 3.31 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# circuit 3 running
# 136 ms ± 3.16 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# circuit 4 running
# 193 ms ± 5.49 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# circuit 5 running
# 323 ms ± 18.5 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 6 running
# 476 ms ± 18.5 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 7 running
# 741 ms ± 34.1 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 8 running
# 1.15 s ± 57.9 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 9 running
# 2.03 s ± 71.4 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 10 running
# 2.99 s ± 122 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 11 running
# 4.12 s ± 140 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 12 running
# 5.72 s ± 285 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 13 running
# 8.02 s ± 350 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 14 running
# 10.9 s ± 337 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 15 running
# 15.7 s ± 611 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 16 running
# 24.2 s ± 641 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 17 running
# 34.5 s ± 2.02 s per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
import pandas as pd
# Convert lists to a dictionary
data = {
    'Circuit Sizes': [safe_eval(s) for s in circuit_sizes],
    'GidNET Average Runtime': gidnet_plus_average_time,  # Added comma
    'GidNET Stdev Runtime': gidnet_plus_std_time,  # Added comma
    'GidNET Width': gidnet_plus_qubit_width,
}

# Assuming pandas is imported as pd
import pandas as pd

# Convert dictionary to DataFrame
df = pd.DataFrame(data)

# Save DataFrame to CSV
df.to_csv('data_supremacy_cct/GidNET_v02_width_and_runtime_supremacy_cct_cycle_13_data.csv', index=False)

# %%
df
# Out:
#     Circuit Sizes  GidNET Average Runtime  GidNET Stdev Runtime  GidNET Width
# 0              16                0.056725              0.003927            10
# 1              20                0.083262              0.003309            12
# 2              25                0.135912              0.003160            13
# 3              30                0.193296              0.005494            16
# 4              36                0.322941              0.018510            19
# 5              42                0.475715              0.018477            20
# 6              49                0.740689              0.034103            23
# 7              56                1.153188              0.057884            25
# 8              64                2.029816              0.071446            30
# 9              72                2.985641              0.122023            29
# 10             81                4.118700              0.139884            32
# 11             90                5.716795              0.284909            32
# 12            100                8.016167              0.349713            35
# 13            110               10.865546              0.336614            36
# 14            121               15.681185              0.610968            38
# 15            132               24.218479              0.641135            42
# 16            144               34.452018              2.024633            44

# %%
qiskit_circuit.depth()
# Out:
# 15

# %%
circuit_sizes = ["4x4", "4x5", "5x5", "5x6", "6x6", "6x7", "7x7", "7x8", "8x8", "8x9",
                "9x9", "9x10", "10x10", "10x11", "11x11", "11x12", "12x12"]

directory_path = "../data"
cycle_num = 13
random_shots = 10


gidnet_plus_average_time = []
gidnet_plus_std_time = []
gidnet_plus_qubit_width = []

for i, num_qubits in enumerate(circuit_sizes):
    print("circuit", i+1, "running")
    qiskit_circuit, _ = create_qiskit_and_qnet_GRCS_circuits(num_qubits, cycle_num, directory_path)
    print(qiskit_circuit.depth())
# Out:
# circuit 1 running
# 15
# circuit 2 running
# 15
# circuit 3 running
# 15
# circuit 4 running
# 15
# circuit 5 running
# 15
# circuit 6 running
# 15
# circuit 7 running
# 15
# circuit 8 running
# 15
# circuit 9 running
# 15
# circuit 10 running
# 15
# circuit 11 running
# 15
# circuit 12 running
# 15
# circuit 13 running
# 15
# circuit 14 running
# 15
# circuit 15 running
# 15
# circuit 16 running
# 15
# circuit 17 running
# 15
