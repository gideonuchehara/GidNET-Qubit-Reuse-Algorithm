# %%
from gidnet_qubit_reuse_algorithm.gidnet_qra import apply_qiskit_qubit_reuse, create_qiskit_and_qnet_GRCS_circuits, safe_eval
import time

# %%
circuit_sizes = ["4x4", "4x5", "5x5", "5x6", "6x6", "6x7", "7x7", "7x8", "8x8", "8x9",
                "9x9", "9x10", "10x10", "10x11", "11x11", "11x12", "12x12"]

directory_path = "../data"
cycle_num = 10

qiskit_average_time = []
qiskit_std_time = []
qiskit_qubit_width = []

for i, num_qubits in enumerate(circuit_sizes):
    print("circuit", i+1, "running")
    qiskit_circuit, _ = create_qiskit_and_qnet_GRCS_circuits(num_qubits, cycle_num, directory_path)
    
    
    qiskit_time = %timeit -o apply_qiskit_qubit_reuse(qiskit_circuit)
    compiled_qiskit_circuit = apply_qiskit_qubit_reuse(qiskit_circuit)

    qiskit_average_time.append(qiskit_time.average)
    qiskit_std_time.append(qiskit_time.stdev)
    qiskit_qubit_width.append(compiled_qiskit_circuit.num_qubits)
# Out:
# circuit 1 running
# 51.6 ms ± 5.28 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# circuit 2 running
# 58.5 ms ± 2.3 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# circuit 3 running
# 83.1 ms ± 4.54 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# circuit 4 running
# 109 ms ± 5.12 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# circuit 5 running
# 137 ms ± 2.71 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# circuit 6 running
# 186 ms ± 12 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# circuit 7 running
# 218 ms ± 25.2 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 8 running
# 246 ms ± 6.74 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 9 running
# 295 ms ± 5.46 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 10 running
# 350 ms ± 11.5 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 11 running
# 414 ms ± 3.46 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 12 running
# 497 ms ± 6.8 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 13 running
# 583 ms ± 16.3 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 14 running
# 662 ms ± 10.5 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 15 running
# 833 ms ± 40.9 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 16 running
# 930 ms ± 24.6 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 17 running
# 1.11 s ± 55.5 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
import pandas as pd
# Convert lists to a dictionary
data = {
    'Circuit Sizes': [safe_eval(s) for s in circuit_sizes],
    'Qiskit Average Runtime': qiskit_average_time,  # Added comma
    'Qiskit Stdev Runtime': qiskit_std_time,  # Added comma
    'Qiskit Width': qiskit_qubit_width,
}

# Assuming pandas is imported as pd
import pandas as pd

# Convert dictionary to DataFrame
df = pd.DataFrame(data)

# Save DataFrame to CSV
df.to_csv('data_supremacy_cct/Qiskit_width_and_runtime_supremacy_cct_cycle_10_data.csv', index=False)

# %%
df
# Out:
#     Circuit Sizes  Qiskit Average Runtime  Qiskit Stdev Runtime  Qiskit Width
# 0              16                0.051565              0.005282            12
# 1              20                0.058531              0.002304            14
# 2              25                0.083053              0.004537            15
# 3              30                0.109407              0.005117            20
# 4              36                0.137236              0.002715            22
# 5              42                0.185624              0.011977            27
# 6              49                0.217696              0.025220            34
# 7              56                0.245982              0.006738            39
# 8              64                0.294548              0.005463            46
# 9              72                0.350293              0.011459            48
# 10             81                0.413808              0.003460            55
# 11             90                0.497307              0.006801            65
# 12            100                0.583493              0.016329            68
# 13            110                0.662201              0.010507            76
# 14            121                0.833395              0.040911            87
# 15            132                0.929602              0.024603            95
# 16            144                1.105594              0.055478           104
