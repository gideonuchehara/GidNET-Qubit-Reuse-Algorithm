# %%
from gidnet_qubit_reuse_algorithm.gidnet_qra import (modified_compile_dynamic_circuit
                                                    )

from helper_functions.benchmarks import generate_circ
from qiskit import QuantumCircuit
import numpy as np

# %%
from gidnet_qubit_reuse_algorithm.gidnet_qra import (safe_eval,
                                                     create_qiskit_and_qnet_GRCS_circuits,)
import time
import os

# %%
circuit_sizes = ["4x4", "4x5", "5x5", "5x6", "6x6", "6x7", "7x7", "7x8", "8x8", "8x9",
                "9x9", "9x10", "10x10", "10x11", "11x11", "11x12", "12x12"]

directory_path = "../data"
cycle_num = 10
random_shots = 10


gidnet_plus_average_time = []
gidnet_plus_std_time = []
gidnet_plus_qubit_width = []

for i, num_qubits in enumerate(circuit_sizes):
    print("circuit", i+1, "running")
    qiskit_circuit, _ = create_qiskit_and_qnet_GRCS_circuits(num_qubits, cycle_num, directory_path)

    gidnet_plus_time = %timeit -o modified_compile_dynamic_circuit(qiskit_circuit, shots=random_shots, algorithm_type="gidnet", improved_gidnet=False)

    compiled_gidnet_circuit = modified_compile_dynamic_circuit(qiskit_circuit, shots=random_shots, algorithm_type="gidnet",
                                                      improved_gidnet=False)

    # Data colation
    gidnet_plus_average_time.append(gidnet_plus_time.average)
    gidnet_plus_std_time.append(gidnet_plus_time.stdev)
    gidnet_plus_qubit_width.append(compiled_gidnet_circuit.num_qubits)
# Out:
# circuit 1 running
# 62 ms ± 3.25 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# circuit 2 running
# 96.9 ms ± 4.61 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# circuit 3 running
# 132 ms ± 21.9 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# circuit 4 running
# 215 ms ± 31.5 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 5 running
# 448 ms ± 14 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 6 running
# 631 ms ± 92.2 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 7 running
# 978 ms ± 105 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 8 running
# 1.42 s ± 163 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 9 running
# 2.51 s ± 127 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 10 running
# 3.5 s ± 419 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 11 running
# 5.08 s ± 841 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 12 running
# 7.43 s ± 198 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 13 running
# 11.1 s ± 346 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 14 running
# 14.1 s ± 1.32 s per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 15 running
# 22.7 s ± 972 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 16 running
# 35.1 s ± 1.08 s per loop (mean ± std. dev. of 7 runs, 1 loop each)
# circuit 17 running
# 49.3 s ± 1.05 s per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# gidnet_plus_qubit_width

# %%
import pandas as pd
# Convert lists to a dictionary
data = {
    'Circuit Sizes': [safe_eval(s) for s in circuit_sizes],
    'GidNET Average Runtime': gidnet_plus_average_time,  # Added comma
    'GidNET Stdev Runtime': gidnet_plus_std_time,  # Added comma
    'GidNET Width': gidnet_plus_qubit_width,
}

# Assuming pandas is imported as pd
import pandas as pd

# Convert dictionary to DataFrame
df = pd.DataFrame(data)

# Save DataFrame to CSV
df.to_csv('data_supremacy_cct/GidNET_v02_width_and_runtime_supremacy_cct_cycle_10_data.csv', index=False)

# %%
df
# Out:
#     Circuit Sizes  GidNET Average Runtime  GidNET Stdev Runtime  GidNET Width
# 0              16                0.062040              0.003254             9
# 1              20                0.096917              0.004613            10
# 2              25                0.132081              0.021850            11
# 3              30                0.215305              0.031526            11
# 4              36                0.447993              0.014006            14
# 5              42                0.630627              0.092225            16
# 6              49                0.977916              0.105219            17
# 7              56                1.421762              0.163471            18
# 8              64                2.510331              0.126645            19
# 9              72                3.504728              0.418815            20
# 10             81                5.081305              0.841469            22
# 11             90                7.430785              0.198408            24
# 12            100               11.068317              0.346358            26
# 13            110               14.129736              1.316785            28
# 14            121               22.724131              0.972493            29
# 15            132               35.063576              1.081751            31
# 16            144               49.262661              1.050735            30

# %%
circuit_sizes = ["4x4", "4x5", "5x5", "5x6", "6x6", "6x7", "7x7", "7x8", "8x8", "8x9",
                "9x9", "9x10", "10x10", "10x11", "11x11", "11x12", "12x12"]

directory_path = "../data"
cycle_num = 10
random_shots = 10


gidnet_plus_average_time = []
gidnet_plus_std_time = []
gidnet_plus_qubit_width = []

for i, num_qubits in enumerate(circuit_sizes):
    print("circuit", i+1, "running")
    qiskit_circuit, _ = create_qiskit_and_qnet_GRCS_circuits(num_qubits, cycle_num, directory_path)
    print(qiskit_circuit.depth())
# Out:
# circuit 1 running
# 12
# circuit 2 running
# 12
# circuit 3 running
# 12
# circuit 4 running
# 12
# circuit 5 running
# 12
# circuit 6 running
# 12
# circuit 7 running
# 12
# circuit 8 running
# 12
# circuit 9 running
# 12
# circuit 10 running
# 12
# circuit 11 running
# 12
# circuit 12 running
# 12
# circuit 13 running
# 12
# circuit 14 running
# 12
# circuit 15 running
# 12
# circuit 16 running
# 12
# circuit 17 running
# 12
